# %%
# Read the data

import numpy as np
import pandas as pd

data = pd.read_csv("Iris.csv")
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# Visualization the data

import seaborn as sns

iris = sns.load_dataset('iris')

# style used as a theme of graph
# for example if we want black
# graph with grid then write "darkgrid"
sns.set_style("whitegrid")

# sepal_length, petal_width are iris
# feature data height used to define
# Height of graph whereas hue store the class of iris dataset.
sns.FacetGrid(iris, hue = "species", height = 8).map(plt.scatter, 'sepal_length', 'petal_width').add_legend()

# sepal_length, petal_length are iris
# feature data height used to define
# Height of graph whereas hue store the class of iris dataset.
sns.FacetGrid(iris, hue = "species", height = 8).map(plt.scatter, 'sepal_length', 'petal_length').add_legend()

# petal_length, petal_width are iris
# feature data height used to define
# Height of graph whereas hue store the class of iris dataset.
sns.FacetGrid(iris, hue = "species", height = 8).map(plt.scatter, 'petal_length', 'petal_width').add_legend()

# %%
#Preprossing the data

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from pandas import DataFrame 

# Load the iris data
iris = datasets.load_iris()

# Data Cleaning
df = DataFrame(data)
    
df.drop('Id',axis=1, inplace=True)
df.shape

# Create a variable for the feature data
x = iris.data

# Create a variable for the target data
y = iris.target

# Random split the data into four new datasets, training features, training outcome, test features, 
# and test outcome. Set the size of the test data to be 30% of the full dataset.
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# Load the standard scaler
sc = StandardScaler()

# Compute the mean and standard deviation based on the training data
sc.fit(x_train)

# Scale the training data to be of mean 0 and of unit variance
x_train_std = sc.transform(x_train)

# Scale the test data to be of mean 0 and of unit variance
x_test_std = sc.transform(x_test)

# Feature Train Data, non-standardized
print(x_train[0:5])

print()

# Feature Train Data, standardized.
print(x_train_std[0:5])

print() 

# Feature Test Data, non-standardized
print(x_test[0:5])

print()

# Feature Test Data, standardized.
print(x_test_std[0:5])
# Out:
# [[5.5 2.4 3.7 1. ]
#  [6.3 2.8 5.1 1.5]
#  [6.4 3.1 5.5 1.8]
#  [6.6 3.  4.4 1.4]
#  [7.2 3.6 6.1 2.5]]
#
# [[-0.4134164  -1.46200287 -0.09951105 -0.32339776]
#  [ 0.55122187 -0.50256349  0.71770262  0.35303182]
#  [ 0.67180165  0.21701605  0.95119225  0.75888956]
#  [ 0.91296121 -0.02284379  0.30909579  0.2177459 ]
#  [ 1.63643991  1.41631528  1.30142668  1.70589097]]
#
# [[6.1 2.8 4.7 1.2]
#  [5.7 3.8 1.7 0.3]
#  [7.7 2.6 6.9 2.3]
#  [6.  2.9 4.5 1.5]
#  [6.8 2.8 4.8 1.4]]
#
# [[ 0.3100623  -0.50256349  0.484213   -0.05282593]
#  [-0.17225683  1.89603497 -1.26695916 -1.27039917]
#  [ 2.23933883 -0.98228318  1.76840592  1.43531914]
#  [ 0.18948252 -0.26270364  0.36746819  0.35303182]
#  [ 1.15412078 -0.50256349  0.54258541  0.2177459 ]]

# %%
# Correlation

sns.lmplot(x = 'SepalLengthCm', y = 'PetalWidthCm', data = df, col = 'Species', hue = 'Species', palette = 'YlGnBu')

sns.lmplot(x = 'SepalLengthCm', y = 'PetalLengthCm', data = df, col = 'Species', hue = 'Species', palette = 'YlGnBu')

sns.lmplot(x = 'PetalLengthCm', y = 'PetalWidthCm', data = df, col = 'Species', hue = 'Species', palette = 'YlGnBu')

# %%
# correlation coefficient
df.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
# conclusion

# High postive correlation = 0.817954 between Sepal Length and Petal Width
# High postive correlation = 0.871754 between Sepal Length and Petal Length
# High postive correlation  = 0.962757 between Patel Length and Petal Width
